# %% [markdown]
# <a href="https://colab.research.google.com/github/Jolayemi-momoh/miniature-bassoon/blob/main/Financial_Health_initial_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
train_df=pd.read_csv('/content/drive/MyDrive/dataorg-financial-health-prediction-challenge20251204-19827-m2tn1n/Train.csv')
train_df.head().T

# %%
test_df=pd.read_csv('/content/drive/MyDrive/dataorg-financial-health-prediction-challenge20251204-19827-m2tn1n/Test.csv')

# %%
train_df.info()

# %%
train_df.isna().sum()

# %%
train_df.duplicated().sum()

# %%
categorical_cols=train_df.select_dtypes(include='object').columns
for col in categorical_cols:
  print(f'---Value counts for {col}---')
  print(train_df[col].value_counts(dropna=False))
  print('\n')

# %%
numerical_cols=train_df.select_dtypes(exclude='object').columns
display('numerical columns are:', numerical_cols.tolist())

# %%
train_df.describe()

# %%
row=train_df[train_df['owner_age']==103]
display(row.T)

# %%
print(train_df['owner_age'].nlargest(10))

# %%
n_cols=5
n_rows=math.ceil(len(categorical_cols)/n_cols)

# %%
fig, axes =plt.subplots(n_rows,n_cols, figsize=(24,5*n_rows))
fig.tight_layout(pad=6.0)
axes=axes.flatten()

# %%
for i,col in enumerate(categorical_cols):
  counts=train_df[col].value_counts(dropna=False)
  sns.barplot(x=counts.index, y=counts.values, ax=axes[i])
  axes[i].set_title(col,fontsize=12,fontweight='bold')
  axes[i].set_xlabel('count')
  axes[i].set_ylabel('')

# %%
for j in range(i+1,len(axes)):
  fig.delaxes(axes[j])

# %%
plt.show()

# %%
fig, axes = plt.subplots(n_rows, n_cols, figsize=(24, 5 * n_rows))
fig.tight_layout(pad=6.0)
axes = axes.flatten()

for i, col in enumerate(categorical_cols):
    counts = train_df[col].value_counts(dropna=False)
    sns.barplot(x=counts.index, y=counts.values, ax=axes[i])
    axes[i].set_title(col, fontsize=12, fontweight='bold')
    axes[i].set_xlabel('count')
    axes[i].set_ylabel('')

# Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.show()
